# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('E:/AIML/ML_linearregression_sample.csv')
df
# Out:
#     direct_net_irridiance   Wind_velocity  ambient_temperature    heat_loss   \
# 0                 4.58114             0.4                  30.2     14.85160
# 1                 3.18834             0.0                  30.7     12.74270
# 2                 3.32113             1.3                  31.1      5.29474
# 3                 3.37828             1.0                  30.6      6.23488
# 4                 1.81527             1.0                  31.0      4.16016
# 5                 2.01655             0.4                  30.8      3.94053
# 6                 2.62564             0.4                  31.0      3.74582
# 7                 3.22008             0.8                  31.3      3.82891
# 8                 2.98386             0.9                  31.5      3.76055
#
#    Outdoor Humidity (%)  Absolute Pressure (mmHg)  heat_gain
# 0                  79.0                     755.9   18.03950
# 1                  80.0                     756.2    9.76156
# 2                  81.0                     756.3    7.28081
# 3                   NaN                     756.3    6.68976
# 4                  82.0                     756.3    5.14517
# 5                  84.0                     756.2    4.00957
# 6                  83.0                     756.4    4.42987
# 7                  83.0                     756.4    5.62730
# 8                  83.0                     756.2    6.22621

# %%
mean_value=df['Outdoor Humidity (%)'].mean()
df['Outdoor Humidity (%)'].fillna(value=mean_value, inplace=True)
df
# Out:
#     direct_net_irridiance   Wind_velocity  ambient_temperature    heat_loss   \
# 0                 4.58114             0.4                  30.2     14.85160
# 1                 3.18834             0.0                  30.7     12.74270
# 2                 3.32113             1.3                  31.1      5.29474
# 3                 3.37828             1.0                  30.6      6.23488
# 4                 1.81527             1.0                  31.0      4.16016
# 5                 2.01655             0.4                  30.8      3.94053
# 6                 2.62564             0.4                  31.0      3.74582
# 7                 3.22008             0.8                  31.3      3.82891
# 8                 2.98386             0.9                  31.5      3.76055
#
#    Outdoor Humidity (%)  Absolute Pressure (mmHg)  heat_gain
# 0                79.000                     755.9   18.03950
# 1                80.000                     756.2    9.76156
# 2                81.000                     756.3    7.28081
# 3                81.875                     756.3    6.68976
# 4                82.000                     756.3    5.14517
# 5                84.000                     756.2    4.00957
# 6                83.000                     756.4    4.42987
# 7                83.000                     756.4    5.62730
# 8                83.000                     756.2    6.22621

# %%
X =df.drop(columns=['heat_gain'])
X
# Out:
#     direct_net_irridiance   Wind_velocity  ambient_temperature    heat_loss   \
# 0                 4.58114             0.4                  30.2     14.85160
# 1                 3.18834             0.0                  30.7     12.74270
# 2                 3.32113             1.3                  31.1      5.29474
# 3                 3.37828             1.0                  30.6      6.23488
# 4                 1.81527             1.0                  31.0      4.16016
# 5                 2.01655             0.4                  30.8      3.94053
# 6                 2.62564             0.4                  31.0      3.74582
# 7                 3.22008             0.8                  31.3      3.82891
# 8                 2.98386             0.9                  31.5      3.76055
#
#    Outdoor Humidity (%)  Absolute Pressure (mmHg)
# 0                79.000                     755.9
# 1                80.000                     756.2
# 2                81.000                     756.3
# 3                81.875                     756.3
# 4                82.000                     756.3
# 5                84.000                     756.2
# 6                83.000                     756.4
# 7                83.000                     756.4
# 8                83.000                     756.2

# %%
y=df['heat_gain']
y
# Out:
# 0    18.03950
# 1     9.76156
# 2     7.28081
# 3     6.68976
# 4     5.14517
# 5     4.00957
# 6     4.42987
# 7     5.62730
# 8     6.22621
# Name: heat_gain, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,random_state=0)
model_LR = LinearRegression().fit(X_train, y_train)
lr = LinearRegression().fit(X_train, y_train)

# %%
print("Training set score: {:.2f}".format(lr.score(X_train, y_train)))
print("Test set score: {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# Training set score: 1.00
# Test set score: -4.78
